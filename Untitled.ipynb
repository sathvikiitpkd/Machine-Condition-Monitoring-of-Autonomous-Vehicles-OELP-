# %%
import librosa.display, os
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.utils import load_img, img_to_array
def load_images_from_path(path, label):
    images = []
    labels = []

    for file in os.listdir(path):
        images.append(img_to_array(load_img(os.path.join(path, file), target_size=(224, 224, 3))))
        labels.append((label))
        
    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 12, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)
        
x = []
y = []

# %%
images, labels = load_images_from_path('./Spectrograms/Healthy', 0)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('./Spectrograms/Ball_defect', 1)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('./Spectrograms/Inner_race_defect', 2)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('./Spectrograms/Outer_race_defect', 3)
show_images(images)
    
x += images
y += labels

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.3, random_state=5)

x_train_norm = np.array(x_train) / 255
x_test_norm = np.array(x_test) / 255
print(x_train_norm.shape)
y_train_encoded = to_categorical(y_train)
y_test_encoded = to_categorical(y_test)
# Out:
# (33, 224, 224, 3)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout
from keras.layers import Flatten, Dense
from tensorflow.keras import layers

# model
model = Sequential([
    layers.Conv2D(filters = 64, kernel_size = 5,activation= 'LeakyReLU', input_shape = (224,224,3)),
    layers.MaxPool2D(2),
    layers.Flatten(),
    layers.Dense(120,activation = 'LeakyReLU'),
    layers.Dense(84, activation = 'LeakyReLU'),
    layers.Dense(4, activation = 'softmax')
])
model.summary()
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics= ['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      4864
#
#  max_pooling2d_1 (MaxPooling  (None, 110, 110, 64)     0
#  2D)
#
#  flatten_1 (Flatten)         (None, 774400)            0
#
#  dense_3 (Dense)             (None, 120)               92928120
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 4)                 340
#
# =================================================================
# Total params: 92,943,488
# Trainable params: 92,943,488
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train_norm, y_train_encoded, validation_data=(x_test_norm, y_test_encoded), batch_size=10, epochs=25)
# Out:
# Epoch 1/25
# 4/4 [==============================] - 3s 728ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4298 - val_accuracy: 0.8667
# Epoch 2/25
# 4/4 [==============================] - 3s 664ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.2854 - val_accuracy: 0.8667
# Epoch 3/25
# 4/4 [==============================] - 3s 685ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1741 - val_accuracy: 0.9333
# Epoch 4/25
# 4/4 [==============================] - 3s 681ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9333
# Epoch 5/25
# 4/4 [==============================] - 3s 736ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.9333
# Epoch 6/25
# 4/4 [==============================] - 3s 760ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9333
# Epoch 7/25
# 4/4 [==============================] - 3s 766ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2410 - val_accuracy: 0.9333
# Epoch 8/25
# 4/4 [==============================] - 3s 735ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.9333
# Epoch 9/25
# 4/4 [==============================] - 3s 739ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.9333
# Epoch 10/25
# 4/4 [==============================] - 3s 775ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1604 - val_accuracy: 0.9333
# Epoch 11/25
# 4/4 [==============================] - 3s 656ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9333
# Epoch 12/25
# 4/4 [==============================] - 3s 653ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9333
# Epoch 13/25
# 4/4 [==============================] - 3s 675ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1825 - val_accuracy: 0.9333
# Epoch 14/25
# 4/4 [==============================] - 3s 783ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1925 - val_accuracy: 0.9333
# Epoch 15/25
# 4/4 [==============================] - 3s 679ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9333
# Epoch 16/25
# 4/4 [==============================] - 3s 697ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1768 - val_accuracy: 0.9333
# Epoch 17/25
# 4/4 [==============================] - 3s 732ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9333
# Epoch 18/25
# 4/4 [==============================] - 3s 742ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9333
# Epoch 19/25
# 4/4 [==============================] - 3s 738ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9333
# Epoch 20/25
# 4/4 [==============================] - 3s 691ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1707 - val_accuracy: 0.9333
# Epoch 21/25
# 4/4 [==============================] - 3s 721ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1815 - val_accuracy: 0.9333
# Epoch 22/25
# 4/4 [==============================] - 3s 728ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9333
# Epoch 23/25
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9333
# Epoch 24/25
# 4/4 [==============================] - 3s 687ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9333
# Epoch 25/25
# 4/4 [==============================] - 3s 697ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1799 - val_accuracy: 0.9333

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
sns.set()

y_predicted = model.predict(x_test_norm)
mat = confusion_matrix(y_test_encoded.argmax(axis=1), y_predicted.argmax(axis=1))
class_labels = ['Healthy', 'Ball_defect', 'Inner_race_defect', 'Outer_race_defect']

sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)

plt.xlabel('Predicted label')
plt.ylabel('Actual label')
